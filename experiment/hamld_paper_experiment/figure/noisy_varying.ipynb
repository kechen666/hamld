# %% [markdown]
# ## 获取随着噪声参数变化的变化情况

# %%
import pandas as pd

# 假设数据存储在名为data.csv的文件中，读取数据
# surface_df_acc = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_surface_code_acc_results_r_d_4p.csv')
# surface_df_acc = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_surface_code_acc_results_20250514_100326.csv')
surface_df_acc = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_surface_code_acc_results_20250604_105139.csv')


# 筛选条件
conditions = (
    surface_df_acc['probability'].isin([0.1, 1, 10,100]) &
    # (surface_df_acc['decoder_method'] == 'EAMLD') &
    (surface_df_acc['d'] == 9)
)

# 根据条件筛选数据
surface_df_acc = surface_df_acc[conditions]

# # 打印结果
# print(result)

# %%
surface_df_acc
# Out:
#                         code_task  d  round  probability noise_model  \
# 0   surface_code:rotated_memory_x  9      9          0.1      si1000
# 1   surface_code:rotated_memory_x  9      9          0.1      si1000
# 2   surface_code:rotated_memory_x  9      9          1.0      si1000
# 3   surface_code:rotated_memory_x  9      9          1.0      si1000
# 4   surface_code:rotated_memory_x  9      9         10.0      si1000
# 5   surface_code:rotated_memory_x  9      9         10.0      si1000
# 6   surface_code:rotated_memory_x  9      9        100.0      si1000
# 7   surface_code:rotated_memory_x  9      9        100.0      si1000
# 8   surface_code:rotated_memory_z  9      9          0.1      si1000
# 9   surface_code:rotated_memory_z  9      9          0.1      si1000
# 10  surface_code:rotated_memory_z  9      9          1.0      si1000
# 11  surface_code:rotated_memory_z  9      9          1.0      si1000
# 12  surface_code:rotated_memory_z  9      9         10.0      si1000
# 13  surface_code:rotated_memory_z  9      9         10.0      si1000
# 14  surface_code:rotated_memory_z  9      9        100.0      si1000
# 15  surface_code:rotated_memory_z  9      9        100.0      si1000
#
#    decoder_method  logical_error_rate  have_stabilizer
# 0            MWPM             0.00050            False
# 1           EAMLD             0.00023            False
# 2            MWPM             0.00493            False
# 3           EAMLD             0.00261            False
# 4            MWPM             0.05159            False
# 5           EAMLD             0.03437            False
# 6            MWPM             0.47816            False
# 7           EAMLD             0.49817            False
# 8            MWPM             0.00042            False
# 9           EAMLD             0.00027            False
# 10           MWPM             0.00579            False
# 11          EAMLD             0.00277            False
# 12           MWPM             0.05549            False
# 13          EAMLD             0.03288            False
# 14           MWPM             0.47746            False
# 15          EAMLD             0.49804            False

# %% [markdown]
# speed

# %%
import pandas as pd

# 假设数据存储在名为data.csv的文件中，读取数据
surface_df_speed = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_surface_code_speed_results_20250604_111843.csv')

# 筛选条件
conditions = (
    surface_df_speed['probability'].isin([0.1, 1, 10,100]) &
    # (surface_df_speed['decoder_method'] == 'EAMLD') &
    (surface_df_speed['d'] == 9)
)

# 根据条件筛选数据
surface_df_speed = surface_df_speed[conditions]

# # 打印结果
# print(result)

# %%
surface_df_speed
# Out:
#                         code_task  d  round  probability noise_model  \
# 0   surface_code:rotated_memory_x  9      9          0.1      si1000
# 1   surface_code:rotated_memory_x  9      9          0.1      si1000
# 2   surface_code:rotated_memory_x  9      9          1.0      si1000
# 3   surface_code:rotated_memory_x  9      9          1.0      si1000
# 4   surface_code:rotated_memory_x  9      9         10.0      si1000
# 5   surface_code:rotated_memory_x  9      9         10.0      si1000
# 6   surface_code:rotated_memory_x  9      9        100.0      si1000
# 7   surface_code:rotated_memory_x  9      9        100.0      si1000
# 8   surface_code:rotated_memory_z  9      9          0.1      si1000
# 9   surface_code:rotated_memory_z  9      9          0.1      si1000
# 10  surface_code:rotated_memory_z  9      9          1.0      si1000
# 11  surface_code:rotated_memory_z  9      9          1.0      si1000
# 12  surface_code:rotated_memory_z  9      9         10.0      si1000
# 13  surface_code:rotated_memory_z  9      9         10.0      si1000
# 14  surface_code:rotated_memory_z  9      9        100.0      si1000
# 15  surface_code:rotated_memory_z  9      9        100.0      si1000
#
#    decoder_method  average_per_round_time  have_stabilizer
# 0            MWPM                0.000010            False
# 1           EAMLD                0.083842            False
# 2            MWPM                0.000011            False
# 3           EAMLD                0.085159            False
# 4            MWPM                0.000016            False
# 5           EAMLD                0.084980            False
# 6            MWPM                0.000111            False
# 7           EAMLD                0.080904            False
# 8            MWPM                0.000010            False
# 9           EAMLD                0.083492            False
# 10           MWPM                0.000011            False
# 11          EAMLD                0.085764            False
# 12           MWPM                0.000018            False
# 13          EAMLD                0.085855            False
# 14           MWPM                0.000109            False
# 15          EAMLD                0.081766            False

# %% [markdown]
# qldpc acc

# %%
import pandas as pd

# 假设数据存储在名为data.csv的文件中，读取数据
# qldpc_df_acc = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_qldpc_code_acc_results_n_72_r_d.csv')
# qldpc_df_acc = pd.read_csv("/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_qldpc_code_acc_results_20250514_100233.csv")
qldpc_df_acc = pd.read_csv("/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_qldpc_code_acc_results_20250604_105122.csv")

# print(qldpc_df_acc['nkd'])
# 筛选条件
conditions = (
    (qldpc_df_acc['nkd'] == "[72, 12, 6]") &
    qldpc_df_acc['probability'].isin([0.1, 1, 10,100])
)

# 根据条件筛选数据
qldpc_df_acc = qldpc_df_acc[conditions]

# # 打印结果
# print(result)

# %%
qldpc_df_acc
# Out:
#                                   code_task          nkd  round  probability  \
# 0   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          0.1
# 1   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          0.1
# 2   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          1.0
# 3   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          1.0
# 4   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1         10.0
# 5   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1         10.0
# 6   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1        100.0
# 7   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1        100.0
# 8   bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          0.1
# 9   bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          0.1
# 10  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          1.0
# 11  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          1.0
# 12  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1         10.0
# 13  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1         10.0
# 14  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1        100.0
# 15  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1        100.0
#
#    noise_model decoder_method  logical_error_rate  have_stabilizer
# 0       si1000         BP+OSD             0.00447            False
# 1       si1000          EAMLD             0.00134            False
# 2       si1000         BP+OSD             0.04578            False
# 3       si1000          EAMLD             0.01420            False
# 4       si1000         BP+OSD             0.37077            False
# 5       si1000          EAMLD             0.14291            False
# 6       si1000         BP+OSD             0.98970            False
# 7       si1000          EAMLD             0.92643            False
# 8       si1000         BP+OSD             0.00474            False
# 9       si1000          EAMLD             0.00170            False
# 10      si1000         BP+OSD             0.04767            False
# 11      si1000          EAMLD             0.01810            False
# 12      si1000         BP+OSD             0.37421            False
# 13      si1000          EAMLD             0.17593            False
# 14      si1000         BP+OSD             0.99323            False
# 15      si1000          EAMLD             0.93586            False

# %% [markdown]
# qldpc speed

# %%
import pandas as pd

# 假设数据存储在名为data.csv的文件中，读取数据
qldpc_df_speed = pd.read_csv('/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/noisy_varying_qldpc_code_speed_results_20250604_111309.csv')

# 筛选条件
conditions = (
    qldpc_df_speed['probability'].isin([0.1, 1, 10,100])
)

# 根据条件筛选数据
qldpc_df_speed = qldpc_df_speed[conditions]

# # 打印结果
# print(result)

# %%
qldpc_df_speed
# Out:
#                                   code_task          nkd  round  probability  \
# 0   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          0.1
# 1   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          0.1
# 2   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          1.0
# 3   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1          1.0
# 4   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1         10.0
# 5   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1         10.0
# 6   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1        100.0
# 7   bivariate_bicycle_code:rotated_memory_x  [72, 12, 6]      1        100.0
# 8   bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          0.1
# 9   bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          0.1
# 10  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          1.0
# 11  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1          1.0
# 12  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1         10.0
# 13  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1         10.0
# 14  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1        100.0
# 15  bivariate_bicycle_code:rotated_memory_z  [72, 12, 6]      1        100.0
#
#    noise_model decoder_method  average_per_round_time  have_stabilizer
# 0       si1000         BP+OSD                0.000042            False
# 1       si1000          EAMLD                0.019690            False
# 2       si1000         BP+OSD                0.000386            False
# 3       si1000          EAMLD                0.019908            False
# 4       si1000         BP+OSD                0.000562            False
# 5       si1000          EAMLD                0.020378            False
# 6       si1000         BP+OSD                0.002039            False
# 7       si1000          EAMLD                0.022324            False
# 8       si1000         BP+OSD                0.000045            False
# 9       si1000          EAMLD                0.017346            False
# 10      si1000         BP+OSD                0.000099            False
# 11      si1000          EAMLD                0.017043            False
# 12      si1000         BP+OSD                0.000284            False
# 13      si1000          EAMLD                0.017090            False
# 14      si1000         BP+OSD                0.001270            False
# 15      si1000          EAMLD                0.018757            False

# %%
# 1. 合并X和Z，logical_error_rate取平均值
surface_df_acc = surface_df_acc.groupby(['d', 'round', 'probability', 'noise_model','decoder_method', 'have_stabilizer'],
                               as_index=False)['logical_error_rate'].mean()
qldpc_df_acc = qldpc_df_acc.groupby(['nkd', 'round', 'probability', 'noise_model','decoder_method', 'have_stabilizer'],
                             as_index=False)['logical_error_rate'].mean()

surface_df_speed = surface_df_speed.groupby(['d', 'round', 'probability', 'noise_model','decoder_method', 'have_stabilizer'],
                               as_index=False)['average_per_round_time'].mean()
qldpc_df_speed = qldpc_df_speed.groupby(['nkd', 'round', 'probability', 'noise_model','decoder_method', 'have_stabilizer'],
                             as_index=False)['average_per_round_time'].mean()

# %%
surface_df_acc_EAMLD = surface_df_acc[surface_df_acc['decoder_method'] == 'EAMLD'].reset_index()
qldpc_df_acc_EAMLD = qldpc_df_acc[qldpc_df_acc['decoder_method'] == 'EAMLD'].reset_index()
surface_df_speed_EAMLD = surface_df_speed[surface_df_speed['decoder_method'] == 'EAMLD'].reset_index()
qldpc_df_speed_EAMLD = qldpc_df_speed[qldpc_df_speed['decoder_method'] == 'EAMLD'].reset_index()

# %%
surface_df_acc_EAMLD
# Out:
#    index  d  round  probability noise_model decoder_method  have_stabilizer  \
# 0      0  9      9          0.1      si1000          EAMLD            False
# 1      2  9      9          1.0      si1000          EAMLD            False
# 2      4  9      9         10.0      si1000          EAMLD            False
# 3      6  9      9        100.0      si1000          EAMLD            False
#
#    logical_error_rate
# 0            0.000250
# 1            0.002690
# 2            0.033625
# 3            0.498105

# %%
surface_ler_reduction = surface_df_acc.pivot(index='probability', columns='decoder_method', values='logical_error_rate') \
                              .apply(lambda row: 100 * (row['MWPM'] - row['EAMLD']) / row['MWPM'], axis=1)

qldpc_ler_reduction = qldpc_df_acc.pivot(index='probability', columns='decoder_method', values='logical_error_rate') \
                              .apply(lambda row: 100 * (row['BP+OSD'] - row['EAMLD']) / row['BP+OSD'], axis=1)

surface_time_reduction  = surface_df_speed.pivot(index='probability', columns='decoder_method', values='average_per_round_time') \
                              .apply(lambda row: 100 * (row['MWPM'] - row['EAMLD']) / row['MWPM'], axis=1)
                              
qldpc_time_reduction = qldpc_df_speed.pivot(index='probability', columns='decoder_method', values='average_per_round_time') \
                              .apply(lambda row: 100 * (row['BP+OSD'] - row['EAMLD']) / row['BP+OSD'], axis=1)

# %%
surface_time_reduction
# Out:
# probability
# 0.1     -811854.673762
# 1.0     -769608.202706
# 10.0    -490810.571389
# 100.0    -74137.562292
# dtype: float64

# %% [markdown]
# 打印为latex格式

# %%
qldpc_df_acc
# Out:
#            nkd  round  probability noise_model decoder_method  \
# 0  [72, 12, 6]      1          0.1      si1000         BP+OSD
# 1  [72, 12, 6]      1          0.1      si1000          EAMLD
# 2  [72, 12, 6]      1          1.0      si1000         BP+OSD
# 3  [72, 12, 6]      1          1.0      si1000          EAMLD
# 4  [72, 12, 6]      1         10.0      si1000         BP+OSD
# 5  [72, 12, 6]      1         10.0      si1000          EAMLD
# 6  [72, 12, 6]      1        100.0      si1000         BP+OSD
# 7  [72, 12, 6]      1        100.0      si1000          EAMLD
#
#    have_stabilizer  logical_error_rate
# 0            False            0.004605
# 1            False            0.001520
# 2            False            0.046725
# 3            False            0.016150
# 4            False            0.372490
# 5            False            0.159420
# 6            False            0.991465
# 7            False            0.931145

# %%
qldpc_df_speed
# Out:
#            nkd  round  probability noise_model decoder_method  \
# 0  [72, 12, 6]      1          0.1      si1000         BP+OSD
# 1  [72, 12, 6]      1          0.1      si1000          EAMLD
# 2  [72, 12, 6]      1          1.0      si1000         BP+OSD
# 3  [72, 12, 6]      1          1.0      si1000          EAMLD
# 4  [72, 12, 6]      1         10.0      si1000         BP+OSD
# 5  [72, 12, 6]      1         10.0      si1000          EAMLD
# 6  [72, 12, 6]      1        100.0      si1000         BP+OSD
# 7  [72, 12, 6]      1        100.0      si1000          EAMLD
#
#    have_stabilizer  average_per_round_time
# 0            False                0.000044
# 1            False                0.018518
# 2            False                0.000242
# 3            False                0.018476
# 4            False                0.000423
# 5            False                0.018734
# 6            False                0.001655
# 7            False                0.020541

# %%
# # 转换为LaTeX格式

for i in range(len(surface_df_acc_EAMLD)):
    prob_i = surface_df_acc_EAMLD['probability'][i]
    prob = surface_df_acc_EAMLD['probability'][i] / 10000
    error_rate = surface_df_acc_EAMLD['logical_error_rate'][i]
    avg_time = surface_df_speed_EAMLD['average_per_round_time'][i]
    # 将科学计数法转换为 LaTeX 格式
    prob_str = "{:.1e}".format(prob).replace("e", r"\times10^{") + "}"
    error_rate_str = "{:.3e}".format(error_rate).replace("e", r"\times10^{") + "}"
    ler_reduction = surface_ler_reduction[prob_i]
    time_reduction = surface_time_reduction[prob_i]
    print(f"& ${prob_str}$ & ${error_rate_str}$ & {avg_time:.2f} & {ler_reduction:.2f} & {time_reduction:.2f} \\\\")
# Out:
# & $1.0\times10^{-05}$ & $2.500\times10^{-04}$ & 0.08 & 45.65 & -811854.67 \\
# & $1.0\times10^{-04}$ & $2.690\times10^{-03}$ & 0.09 & 49.81 & -769608.20 \\
# & $1.0\times10^{-03}$ & $3.363\times10^{-02}$ & 0.09 & 37.20 & -490810.57 \\
# & $1.0\times10^{-02}$ & $4.981\times10^{-01}$ & 0.08 & -4.25 & -74137.56 \\

# %%
import numpy as np
for i in range(len(surface_df_acc_EAMLD)):
    prob_i = surface_df_acc_EAMLD['probability'][i]
    prob_str = r"10^{" + str(int(np.log10(prob_i / 10000))) + "}"
    
    # 格式化 LER
    error_rate = surface_df_acc_EAMLD['logical_error_rate'][i]
    coeff, exp = f"{error_rate:.1e}".split("e")
    coeff = str(round(float(coeff), 2)).rstrip("0").rstrip(".")  # 精简有效位
    exp = int(exp)
    error_rate_str = f"{coeff}\\times10^{{{exp}}}"

    # 时间保留两位小数
    avg_time = surface_df_speed_EAMLD['average_per_round_time'][i]
    avg_time_str = f"{avg_time:.2f}"

    # LER下降百分比
    ler_reduction = surface_ler_reduction[prob_i]
    ler_reduction_str = f"{ler_reduction:.2f}"

    # 时间下降比例：科学计数法，2 位有效数字
    time_reduction = surface_time_reduction[prob_i]
    coeff2, exp2 = f"{time_reduction:.1e}".split("e")
    coeff2 = str(round(float(coeff2), 2)).rstrip("0").rstrip(".")
    time_reduction_str = f"{coeff2}\\times10^{{{int(exp2)}}}"

    print(f"& ${prob_str}$ & ${error_rate_str}$ & {avg_time_str} & {ler_reduction_str} & ${time_reduction_str}$ \\\\")
# Out:
# & $10^{-5}$ & $2.5\times10^{-4}$ & 0.08 & 45.65 & $-8.1\times10^{5}$ \\
# & $10^{-4}$ & $2.7\times10^{-3}$ & 0.09 & 49.81 & $-7.7\times10^{5}$ \\
# & $10^{-3}$ & $3.4\times10^{-2}$ & 0.09 & 37.20 & $-4.9\times10^{5}$ \\
# & $10^{-2}$ & $5\times10^{-1}$ & 0.08 & -4.25 & $-7.4\times10^{4}$ \\

# %%
# # # 转换为LaTeX格式

# for i in range(len(qldpc_df_acc_EAMLD)):
#     prob_i = qldpc_df_acc_EAMLD['probability'][i]
#     prob = qldpc_df_acc_EAMLD['probability'][i] / 10000
#     error_rate = qldpc_df_acc_EAMLD['logical_error_rate'][i]
#     avg_time = qldpc_df_speed_EAMLD['average_per_round_time'][i]
#     # 将科学计数法转换为 LaTeX 格式
#     prob_str = "{:.1e}".format(prob).replace("e", r"\times10^{") + "}"
#     error_rate_str = "{:.3e}".format(error_rate).replace("e", r"\times10^{") + "}"
#     ler_reduction = qldpc_ler_reduction[prob_i]
#     time_reduction = qldpc_time_reduction[prob_i]
#     print(f"& ${prob_str}$ & ${error_rate_str}$ & {avg_time:.4f} & {ler_reduction:.2f} & {time_reduction:.2f} \\\\")

# %%
import numpy as np
for i in range(len(qldpc_df_acc_EAMLD)):
    prob_i = qldpc_df_acc_EAMLD['probability'][i]
    prob_str = r"10^{" + str(int(np.log10(prob_i / 10000))) + "}"
    
    # 格式化 LER
    error_rate = qldpc_df_acc_EAMLD['logical_error_rate'][i]
    coeff, exp = f"{error_rate:.1e}".split("e")
    coeff = str(round(float(coeff), 2)).rstrip("0").rstrip(".")  # 精简有效位
    exp = int(exp)
    error_rate_str = f"{coeff}\\times10^{{{exp}}}"

    # 时间保留两位小数
    avg_time = qldpc_df_speed_EAMLD['average_per_round_time'][i]
    avg_time_str = f"{avg_time:.2f}"

    # LER下降百分比
    ler_reduction = qldpc_ler_reduction[prob_i]
    ler_reduction_str = f"{ler_reduction:.1f}"

    # 时间下降比例：科学计数法，2 位有效数字
    time_reduction = qldpc_time_reduction[prob_i]
    coeff2, exp2 = f"{time_reduction:.1e}".split("e")
    coeff2 = str(round(float(coeff2), 2)).rstrip("0").rstrip(".")
    time_reduction_str = f"{coeff2}\\times10^{{{int(exp2)}}}"

    print(f"& ${prob_str}$ & ${error_rate_str}$ & {avg_time_str} & {ler_reduction_str} & ${time_reduction_str}$ \\\\")
# Out:
# & $10^{-5}$ & $1.5\times10^{-3}$ & 0.02 & 67.0 & $-4.2\times10^{4}$ \\
# & $10^{-4}$ & $1.6\times10^{-2}$ & 0.02 & 65.4 & $-7.5\times10^{3}$ \\
# & $10^{-3}$ & $1.6\times10^{-1}$ & 0.02 & 57.2 & $-4.3\times10^{3}$ \\
# & $10^{-2}$ & $9.3\times10^{-1}$ & 0.02 & 6.1 & $-1.1\times10^{3}$ \\
