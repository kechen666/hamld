# %% [markdown]
# # bias 实验数据

# %% [markdown]
# ## 预处理

# %%
import pandas as pd

# 文件路径

# qldpc_file_path = "/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/biased_measurement_qldpc_code_acc_results_new.csv"
qldpc_file_path = "/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/biased_measurement_qldpc_code_acc_results_20250513_230153.csv"

# 读取CSV文件
qldpc_df = pd.read_csv(qldpc_file_path)

# 删除无关参数列
qldpc_df = qldpc_df.drop(columns=['round','approximate_param', 'priority', 'priority_topk','have_stabilizer' ,'noise_model', 'probability'])

# surface_file_path = "/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/biased_measurement_surface_code_acc_results_depolarization.csv"
surface_file_path = "/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/biased_measurement_surface_code_acc_results_20250513_230123.csv"

# surface_file_path ="/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/result/biased_measurement_surface_code_acc_results_new.csv"
surface_df = pd.read_csv(surface_file_path)
# print(surface_df)
surface_df = surface_df[surface_df['noise_model'] != 'depolarization']
# 删除无关参数列
surface_df = surface_df.drop(columns=['round','approximate_param', 'priority', 'priority_topk','have_stabilizer' ,'noise_model', 'probability'])

# %%
surface_df
# Out:
#                          code_task  detector_number  d decoder_method  \
# 0    surface_code:rotated_memory_x                4  3           MWPM
# 1    surface_code:rotated_memory_x                4  3           MWPM
# 2    surface_code:rotated_memory_x                4  3           MWPM
# 3    surface_code:rotated_memory_x                4  3           MWPM
# 4    surface_code:rotated_memory_x                4  3           MWPM
# ..                             ...              ... ..            ...
# 187  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 188  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 189  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 190  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 191  surface_code:rotated_memory_z               40  9     EAMLD-bias
#
#      logical_error_rate  is_biased  biased_param
# 0               0.00538      False          0.25
# 1               0.00538      False          0.50
# 2               0.00538      False          1.00
# 3               0.00538      False          2.00
# 4               0.00538       True          0.25
# ..                  ...        ...           ...
# 187             0.01817      False          2.00
# 188             0.01817       True          0.25
# 189             0.01817       True          0.50
# 190             0.01817       True          1.00
# 191             0.01817       True          2.00
#
# [192 rows x 7 columns]

# %% [markdown]
# qldpc_df

# %%
qldpc_df
# Out:
#                                    code_task  detector_number            nkd  \
# 0    bivariate_bicycle_code:rotated_memory_x               36    [72, 12, 6]
# 1    bivariate_bicycle_code:rotated_memory_x               36    [72, 12, 6]
# 2    bivariate_bicycle_code:rotated_memory_x               36    [72, 12, 6]
# 3    bivariate_bicycle_code:rotated_memory_x               36    [72, 12, 6]
# 4    bivariate_bicycle_code:rotated_memory_x               36    [72, 12, 6]
# ..                                       ...              ...            ...
# 187  bivariate_bicycle_code:rotated_memory_z               72  [144, 12, 12]
# 188  bivariate_bicycle_code:rotated_memory_z               72  [144, 12, 12]
# 189  bivariate_bicycle_code:rotated_memory_z               72  [144, 12, 12]
# 190  bivariate_bicycle_code:rotated_memory_z               72  [144, 12, 12]
# 191  bivariate_bicycle_code:rotated_memory_z               72  [144, 12, 12]
#
#     decoder_method  logical_error_rate  is_biased  biased_param
# 0           BP+OSD             0.24889      False          0.25
# 1           BP+OSD             0.24889      False          0.50
# 2           BP+OSD             0.24889      False          1.00
# 3           BP+OSD             0.24889      False          2.00
# 4           BP+OSD             0.36823       True          0.25
# ..             ...                 ...        ...           ...
# 187     EAMLD-bias             0.29543      False          2.00
# 188     EAMLD-bias             0.30401       True          0.25
# 189     EAMLD-bias             0.30561       True          0.50
# 190     EAMLD-bias             0.30626       True          1.00
# 191     EAMLD-bias             0.30767       True          2.00
#
# [192 rows x 7 columns]

# %%
surface_df
# Out:
#                          code_task  detector_number  d decoder_method  \
# 0    surface_code:rotated_memory_x                4  3           MWPM
# 1    surface_code:rotated_memory_x                4  3           MWPM
# 2    surface_code:rotated_memory_x                4  3           MWPM
# 3    surface_code:rotated_memory_x                4  3           MWPM
# 4    surface_code:rotated_memory_x                4  3           MWPM
# ..                             ...              ... ..            ...
# 187  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 188  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 189  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 190  surface_code:rotated_memory_z               40  9     EAMLD-bias
# 191  surface_code:rotated_memory_z               40  9     EAMLD-bias
#
#      logical_error_rate  is_biased  biased_param
# 0               0.00538      False          0.25
# 1               0.00538      False          0.50
# 2               0.00538      False          1.00
# 3               0.00538      False          2.00
# 4               0.00538       True          0.25
# ..                  ...        ...           ...
# 187             0.01817      False          2.00
# 188             0.01817       True          0.25
# 189             0.01817       True          0.50
# 190             0.01817       True          1.00
# 191             0.01817       True          2.00
#
# [192 rows x 7 columns]

# %%
qldpc_df.columns
# Out:
# Index(['code_task', 'detector_number', 'nkd', 'decoder_method',
#        'logical_error_rate', 'is_biased', 'biased_param'],
#       dtype='object')

# %%
# 1. 合并X和Z，logical_error_rate取平均值
surface_r1_df = surface_df.groupby(['detector_number', 'd', 'decoder_method', 'is_biased', 'biased_param'],
                               as_index=False)['logical_error_rate'].mean()
qldpc_r1_df = qldpc_df.groupby(['detector_number', 'nkd', 'decoder_method', 'is_biased', 'biased_param'],
                             as_index=False)['logical_error_rate'].mean()

# %%
surface_r1_df = surface_r1_df[~((surface_r1_df['decoder_method'] == 'EAMLD-bias') & (surface_r1_df['is_biased'] == False))]

qldpc_r1_df = qldpc_r1_df[~((qldpc_r1_df['decoder_method'] == 'EAMLD-bias') & (qldpc_r1_df['is_biased'] == False))]

# %%
# 统一使用四组数据：
surface_r1_df = surface_r1_df[surface_r1_df['biased_param'] != 3.0]

# %%
surface_d3_df = surface_r1_df[surface_r1_df['d'] == 3]
surface_d5_df = surface_r1_df[surface_r1_df['d'] == 5]
surface_d7_df = surface_r1_df[surface_r1_df['d'] == 7]
surface_d9_df = surface_r1_df[surface_r1_df['d'] == 9]

# %%
qldpc_nkd_72_12_6_df = qldpc_r1_df[qldpc_r1_df['nkd'] == "[72, 12, 6]"]
qldpc_nkd_90_8_10_df = qldpc_r1_df[qldpc_r1_df['nkd'] == "[90, 8, 10]"]
qldpc_nkd_108_8_10_df = qldpc_r1_df[qldpc_r1_df['nkd'] == "[108, 8, 10]"]
qldpc_nkd_144_12_12_df = qldpc_r1_df[qldpc_r1_df['nkd'] == "[144, 12, 12]"]

# %% [markdown]
# ## 图例

# %%
# colors = {
#     "MWPM": '#FF00FF',  # 品红，和其他颜色在色相上有较大差异
#     "BP+OSD": '#FFA500',  # 橙色，与其他颜色的色调不同
#     "EAMLD": '#00FFFF',  # 青色，明亮且与其他颜色有明显区别
#     "EAMLD-bias": '#FF6347',  # 鲑鱼红，与其他颜色在色调和明度上有不同
# }
# colors = {
#     "MWPM": '#FF69B4',     # 深粉红（保留原色，经典算法高对比）
#     "BP+OSD": '#FF4500',   # 橙红
#     "EAMLD": '#40E0D0',    # 青色
#     "EAMLD-bias": '#FF6347',
# }

colors = {
    "MWPM": '#3A6EA5',     # 
    "BP+OSD": '#E89C31',   # 
    "EAMLD": '#9BBF88',    # 
    # "EAMLD-bias": '#FF6347',
}

# markers = {
#     "MWPM": '.', 
#     "BP+OSD": '.', 
#     "EAMLD": '.', 
#     "EAMLD-bias": '.', 
# }

markers = {
    True: '.', 
    False: 'X', 
}


# linestyles = {
#     "MWPM": '-', 
#     "BP+OSD": '-', 
#     "EAMLD": '-', 
#     "EAMLD-bias": '-', 
# }
linestyles = {
    True: '-', 
    False: '--', 
}

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from pathlib import Path

plt.rcParams['font.family'] = 'serif'  # 使用衬线字体

# 创建图例元素
legend_elements = []
for key in colors.keys():
    for key1 in markers.keys():
        if key1 == False:
            if key in ["EAMLD-bias"]:
                continue
        if key in ["EAMLD-bias"]:
            line = Line2D([0], [0], color=colors[key], marker="+", linestyle=linestyles[key1],
                        label=f"{key}", markersize=20*1.5, linewidth=4*1.2, markeredgewidth=1.5)
            legend_elements.append(line)
        else:
            if key1 == True:
                line = Line2D([0], [0], color=colors[key], marker=markers[key1], linestyle=linestyles[key1],
                            label=f"{key}", markersize=20*1.5, linewidth=4*1.2, markeredgewidth=1.5)
                legend_elements.append(line)
            else:
                line = Line2D([0], [0], color=colors[key], marker=markers[key1], linestyle=linestyles[key1],
                            label=f"{key}*", markersize=20*1.5, linewidth=4*1.2, markeredgewidth=1.5)
                legend_elements.append(line)
        

# prop={'size': 24*1.2, 'family': 'serif', 'weight': 'bold'}
prop={'size': 28*1.2}

# 创建一个空的图形
fig, ax = plt.subplots(figsize=(len(legend_elements)*2, 1))  # 根据图例数量调整宽度

ax.legend(handles=legend_elements, loc='center', ncol=len(legend_elements), 
          frameon=False, borderpad=0, prop=prop)  # 设置字体大小为12

# 隐藏坐标轴和边框
ax.axis('off')
plt.subplots_adjust(left=0, right=1, top=1, bottom=0)  # 去除空白边距

# 保存图片为PDF
save_dir = Path("/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/figure/bias_performance")
save_dir.mkdir(parents=True, exist_ok=True)
save_path = save_dir / f"bias_performance_result_legend.pdf"
plt.savefig(save_path, format="pdf", dpi=300, bbox_inches='tight')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path


def plot_logical_error_rate_ax(ax, df, name, code, colors, markers, linestyles, x_ticks=[0.25, 0.5, 1, 2],
                               show_x_ticks=True, show_y_ticks=True,
                               y_ticks=[0.005,0.01, 0.1, 1], use_markevery=True):
    # sorted_methods = ['MWPM', 'BP+OSD', 'EAMLD', 'EAMLD-bias']
    sorted_methods = ['MWPM', 'BP+OSD', 'EAMLD']
    sorted_is_bias = [True, False]
    
    if use_markevery:
        markevery = (0, df['decoder_method'].nunique()*df['is_biased'].nunique())
        # markevery = (0, 2)
    else:
        markevery = None

    for label in sorted_methods:
        for lable1 in sorted_is_bias:
            if lable1 == False:
                if label in ["EAMLD-bias"]:
                    continue
            if label in df['decoder_method'].unique() and lable1 in df['is_biased'].unique():
                if label in ["EAMLD-bias"]:
                    group = df[(df['decoder_method'] == label) & (df['is_biased'] == lable1)]
                    ax.plot(group['biased_param'],
                            group['logical_error_rate'],
                            color=colors[label],
                            marker="+",
                            linestyle=linestyles[lable1],
                            # label=label,
                            alpha=0.8,
                            markersize=20,
                            linewidth=4,
                            markevery=markevery,
                            markeredgewidth=1.5)
                elif label not in ["BP+OSD"]:
                    group = df[(df['decoder_method'] == label) & (df['is_biased'] == lable1)]
                    ax.plot(group['biased_param'],
                            group['logical_error_rate'],
                            color=colors[label],
                            marker=markers[lable1],
                            linestyle=linestyles[lable1],
                            # label=label,
                            alpha=0.8,
                            markersize=20,
                            linewidth=4,
                            markevery=markevery,
                            markeredgewidth=1.5)
                    if use_markevery:
                        markevery = (markevery[0] + 1 , markevery[1])
                else:
                    group = df[(df['decoder_method'] == label) & (df['is_biased'] == lable1)]
                    ax.plot(group['biased_param'],
                            group['logical_error_rate'],
                            color=colors[label],
                            marker=markers[lable1],
                            linestyle=linestyles[lable1],
                            # label=label,
                            alpha=0.8,
                            markersize=20*1.2,
                            linewidth=4*1.2,
                            markevery=None,
                            markeredgewidth=1.5*1.2)

    # title = f'{code} with {name}'
    
    if code == "Surface Code":
        title = f'{code} {name}'
        ax.set_title(title, fontsize=28, pad=12)
    else:
        title = f'{code} {name}'
        ax.set_title(title, fontsize=28, pad=12)
    ax.set_title(title, fontsize=28)

    if show_x_ticks:
        ax.set_xlabel('β', fontsize=24*1.2)
        ax.set_xticks(x_ticks)
        ax.tick_params(axis='x', which='minor', bottom=False)
        ax.tick_params(axis='x', labelsize=18*1.2)
    else:
        ax.set_xticks(x_ticks)
        ax.set_xticklabels([])
        ax.tick_params(axis='x', which='minor', bottom=False)
        ax.tick_params(axis='x', labelsize=18*1.2)

    ax.set_yscale('log')

    if show_y_ticks:
        ax.set_ylabel('Mean X/Z Logical Error Rate', fontsize=24*1.2)
        ax.set_yticks(ticks=y_ticks)
        ax.tick_params(axis='y', which='major', labelsize=18*1.2)
    else:
        ax.set_yticks(y_ticks)
        ax.set_yticklabels([])
        ax.tick_params(axis='y', which='major', labelsize=18*1.2)

    ax.minorticks_on()
    ax.grid(True, linestyle='--', alpha=0.8, which='major', axis='x')
    ax.grid(False, which='minor', axis='x')
    ax.grid(True, linestyle='--', alpha=0.8, which='major', axis='y')
    ax.grid(True, linestyle=':', alpha=0.4, which='minor', axis='y')


# fig, axes = plt.subplots(1, 4, figsize=(40, 8), sharey=True)
fig, axes = plt.subplots(1, 4, figsize=(28, 7))

# plot_logical_error_rate_ax(axes[0], surface_d3_df, name="d=3", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=False, show_y_ticks=True)
# plot_logical_error_rate_ax(axes[1], surface_d5_df, name="d=9", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=False, show_y_ticks=False, x_ticks=[100, 300, 600], use_markevery=False)
# plot_logical_error_rate_ax(axes[2], qldpc_nkd_72_12_6_df, name="nkd=[72,12,6]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=False, show_y_ticks=False, x_ticks=[30, 50, 70], use_markevery=False)
# plot_logical_error_rate_ax(axes[3], qldpc_nkd_144_12_12_df, name="nkd=[144,12,12]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=False, show_y_ticks=False, x_ticks=[100, 500, 1000, 2000], use_markevery=False)

# plot_logical_error_rate_ax(axes[0], surface_d3_df, name="d=3", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=True, use_markevery=True)
# plot_logical_error_rate_ax(axes[1], surface_d5_df, name="d=9", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=True)
# plot_logical_error_rate_ax(axes[2], qldpc_nkd_72_12_6_df, name="nkd=[72,12,6]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=True)
# plot_logical_error_rate_ax(axes[3], qldpc_nkd_144_12_12_df, name="nkd=[144,12,12]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=True)


plot_logical_error_rate_ax(axes[0], surface_d3_df, name="[[17,1,3]]", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=True, use_markevery=True)
plot_logical_error_rate_ax(axes[1], surface_d5_df, name="[[161,1,9]]", code='Surface Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=True)
plot_logical_error_rate_ax(axes[2], qldpc_nkd_72_12_6_df, name="[[144,12,6]]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=False)
plot_logical_error_rate_ax(axes[3], qldpc_nkd_144_12_12_df, name="[[288,12,12]]", code='QLDPC Code', colors=colors, markers=markers, linestyles=linestyles, show_x_ticks=True, show_y_ticks=False, use_markevery=False)


# 调整子图之间的间距
plt.subplots_adjust(wspace=0.05)  # wspace 控制子图之间的水平间距

# 保存图片为PDF
save_dir = Path("/home/normaluser/ck/epmld/experiment/epmld_paper_experiment/figure/bias_performance")
save_dir.mkdir(parents=True, exist_ok=True)
save_path = save_dir / "bias_merged_plots_row.pdf"
plt.savefig(save_path, format="pdf", dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# 降低效果

# %%
eamld_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'EAMLD']
eamld_data = eamld_data[eamld_data["is_biased"] == True]['logical_error_rate']

eamld_bias_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'EAMLD-bias']['logical_error_rate']

# %%
# eamld_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'EAMLD']['logical_error_rate']
# bposd_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'EAMLD-bias']['logical_error_rate']

# 计算降低率
reduction_rates = (eamld_data.values - eamld_bias_data.values) / eamld_data.values

# 计算平均降低率
average_reduction_rate = reduction_rates.mean()

print(f"EAMLD-bias 的 logical_error_rate 相对于 EAMLD 的 logical_error_rate 的平均降低率为: {average_reduction_rate:.3%}")
# Out:
# EAMLD-bias 的 logical_error_rate 相对于 EAMLD 的 logical_error_rate 的平均降低率为: 0.734%

# %% [markdown]
# 鲁棒性

# %%
bposd_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'BP+OSD']
bposd_bias_data = bposd_data[bposd_data["is_biased"] == True]['logical_error_rate']
bposd_data = bposd_data[bposd_data["is_biased"] == False]['logical_error_rate']

# %%
# 计算上升率
increase_rate = (bposd_bias_data.values - bposd_data.values) / bposd_data.values

# 计算平均上升率
average_increase_rate = increase_rate.mean()

# 输出结果
print(f"BP+OSD在有偏置情况下的平均逻辑错误率上升率为: {average_increase_rate:.2%}")
# Out:
# BP+OSD在有偏置情况下的平均逻辑错误率上升率为: 47.52%

# %%
bposd_data = qldpc_nkd_144_12_12_df[qldpc_nkd_144_12_12_df['decoder_method'] == 'BP+OSD']
bposd_bias_data = bposd_data[bposd_data["is_biased"] == True]['logical_error_rate']
bposd_data = bposd_data[bposd_data["is_biased"] == False]['logical_error_rate']

# 计算上升率
increase_rate = (bposd_bias_data.values - bposd_data.values) / bposd_data.values

# 计算平均上升率
average_increase_rate = increase_rate.mean()

# 输出结果
print(f"144_12_12, BP+OSD在有偏置情况下的平均逻辑错误率上升率为: {average_increase_rate:.2%}")
# Out:
# 144_12_12, BP+OSD在有偏置情况下的平均逻辑错误率上升率为: 37.24%

# %%
eamld_data = qldpc_nkd_72_12_6_df[qldpc_nkd_72_12_6_df['decoder_method'] == 'EAMLD']
eamld_bias_data = eamld_data[eamld_data["is_biased"] == True]['logical_error_rate']
eamld_data = eamld_data[eamld_data["is_biased"] == False]['logical_error_rate']

# 计算上升率
increase_rate = (eamld_bias_data.values - eamld_data.values) / eamld_data.values

# 计算平均上升率
average_increase_rate = increase_rate.mean()

# 输出结果
print(f"EAMLD在有偏置情况下的平均逻辑错误率上升率为: {average_increase_rate:.2%}")
# Out:
# EAMLD在有偏置情况下的平均逻辑错误率上升率为: 4.62%

# %%
eamld_data = qldpc_nkd_144_12_12_df[qldpc_nkd_144_12_12_df['decoder_method'] == 'EAMLD']
eamld_bias_data = eamld_data[eamld_data["is_biased"] == True]['logical_error_rate']
eamld_data = eamld_data[eamld_data["is_biased"] == False]['logical_error_rate']

# 计算上升率
increase_rate = (eamld_bias_data.values - eamld_data.values) / eamld_data.values

# 计算平均上升率
average_increase_rate = increase_rate.mean()

# 输出结果
print(f"EAMLD在有偏置情况下的平均逻辑错误率上升率为: {average_increase_rate:.2%}")
# Out:
# EAMLD在有偏置情况下的平均逻辑错误率上升率为: 4.01%
